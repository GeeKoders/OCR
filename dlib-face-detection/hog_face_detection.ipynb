# %%
# USAGE
# python hog_face_detection.py --image images/HID_1.png

import helpers
import argparse
import imutils
import time
import dlib
import cv2

print("[INFO] loading HOG + Linear SVM face detector...")
detector = dlib.get_frontal_face_detector()
image = cv2.imread('images/HID_1.png')
image = imutils.resize(image, width=600)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

start = time.time()
rects = detector(rgb, 1)
end = time.time()
print("[INFO] face detection took {:.4f} seconds".format(end - start))

boxes = [helpers.convert_and_trim_bb(image, r) for r in rects]

for (x, y, w, h) in boxes:
	cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

if len(boxes) == 0:
  print('Fasle')
else:
  print('True')

plt.imshow(image)
# Out:
# [INFO] loading HOG + Linear SVM face detector...
# [INFO] face detection took 0.0673 seconds
# Fasle

# %%
 ! python hog_face_detection.py --image images/family.jpg
# Out:
# [INFO] loading HOG + Linear SVM face detector...
# [INFO[ performing face detection with dlib...
# [INFO] face detection took 0.2446 seconds
# : cannot connect to X server
